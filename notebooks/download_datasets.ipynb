# %% [markdown]
# # Datasets

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datasets import load_dataset

# %%
ds = load_dataset("angrygiraffe/claude-opus-4.6-4.7-reasoning-8.7k")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# code_train.jsonl:   0%|          | 0.00/12.5M [00:00<?, ?B/s]
# code_train_no_reasoning.jsonl: 0.00B [00:00, ?B/s]
# full_train.jsonl:   0%|          | 0.00/71.4M [00:00<?, ?B/s]
# full_train_no_reasoning.jsonl:   0%|          | 0.00/48.4M [00:00<?, ?B/s]
# instruct_train.jsonl:   0%|          | 0.00/60.6M [00:00<?, ?B/s]
# instruct_train_no_reasoning.jsonl:   0%|          | 0.00/41.0M [00:00<?, ?B/s]
# roleplay_train.jsonl:   0%|          | 0.00/10.8M [00:00<?, ?B/s]
# roleplay_train_no_reasoning.jsonl: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/38504 [00:00<?, ? examples/s]

# %%
def from_openai_format_to_raw_text(messages):
    # Add special tokens to indicate the start of user and assistant messages
    raw_text = ""
    for message in messages:
        if message["role"] == "user":
            raw_text += "<user>" + message["content"] + "</user>"
        elif message["role"] == "assistant":
            raw_text += "</assistant|>" + message["content"] + "</assistant|>"
        elif message["role"] == "system":
            raw_text += "<system>" + message["content"] + "</system>"
        else:
            print(f"Unknown role: {message['role']}")
    return raw_text

# %%
# Save dataset to disk
df: pd.DataFrame = ds["train"].to_pandas()
df["processed"] = df["messages"].apply(lambda x: from_openai_format_to_raw_text(x))
# df["input_length_chars"] = df["processed"].apply(len)
# Drop the original messages column
df = df.drop(columns=["messages"])
df.to_csv("claude_opus_4.6_4.7_reasoning_8.7k.csv", index=False)
df
# Out:
#                category            model  \
# 0                coding  claude-opus-4-6
# 1                coding  claude-opus-4-6
# 2                coding  claude-opus-4-6
# 3                coding  claude-opus-4-7
# 4                coding  claude-opus-4-7
# ...                 ...              ...
# 38499  roleplay_villain  claude-opus-4-6
# 38500  roleplay_villain  claude-opus-4-6
# 38501   narrative_prose  claude-opus-4-6
# 38502  roleplay_villain  claude-opus-4-6
# 38503     roleplay_hero  claude-opus-4-7
#
#                                                processed
# 0      <system>You are a computer science tutor. Expl...
# 1      <system>You are a computer science tutor. Expl...
# 2      <system>You are a DevOps engineer. Focus on re...
# 3      <system>You are a senior React/TypeScript engi...
# 4      <system>You are an event-driven systems engine...
# ...                                                  ...
# 38499  <system>You are Iago, now speaking separately ...
# 38500  <system>You are Cersei Lannister of House Lann...
# 38501  <system>You are a literary fiction writer. Cha...
# 38502  <system>You are Erik Lehnsherr — Magneto — sea...
# 38503  <system>You are Éowyn, Lady of Ithilien, marri...
#
# [38504 rows x 3 columns]

# %%
plt.figure(figsize=(10,8))
order = df["category"].value_counts().index
sns.countplot(y="category", data=df, order=order, palette="viridis")
plt.xlabel("Frequency")
plt.ylabel("Category")
plt.title("Count of Entries per Category")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_580105/656795141.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="category", data=df, order=order, palette="viridis")
